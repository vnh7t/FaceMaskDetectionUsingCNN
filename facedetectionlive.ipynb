# %%
import cv2
face_clsfr=cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')



labels_dict={0:'MASK',1:'NO MASK'}
color_dict={0:(0,255,0),1:(0,0,255)}
# load a saved model
from keras.models import load_model
saved_model = load_model('facemaskdetectionV1.h5')
source=cv2.VideoCapture(0)
while(True):

    ret,img=source.read()
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_clsfr.detectMultiScale(gray,
        scaleFactor=1.03,
        minNeighbors=3,
        minSize=(122,122),
        flags=cv2.CASCADE_SCALE_IMAGE)  

    for (x,y,w,h) in faces:
    
        face_img=gray[y:y+w,x:x+w]
        resized=cv2.resize(face_img,(122,122))
        normalized=resized/255.0
        reshaped=np.reshape(normalized,(1,122,122,1))
        result=saved_model.predict(reshap
                                   ed)

        label=np.argmax(result,axis=1)[0]
      
        cv2.rectangle(img,(x,y),(x+w,y+h),color_dict[label],2)
        cv2.rectangle(img,(x,y-40),(x+w,y),color_dict[label],-1)
        cv2.putText(img, labels_dict[label], (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
        
        
    cv2.imshow('LIVE',img)
    key=cv2.waitKey(1)
    
    if(key==27):
        break
        
cv2.destroyAllWindows()
source.release()

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\vnh7t\anaconda3\lib\site-packages (4.5.4.60)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\vnh7t\anaconda3\lib\site-packages (from opencv-python) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# Installing collected packages: keras
# Successfully installed keras-2.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
# ERROR: No matching distribution found for tensorflow

# %%
import numpy as np
